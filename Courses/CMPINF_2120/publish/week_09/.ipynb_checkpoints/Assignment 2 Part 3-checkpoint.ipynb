# %% [markdown]
# ## Assignment 2 Part 3
# ### Import Modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import statsmodels.api as sm

# %%
from sklearn.linear_model import LinearRegression

# %%
from statsmodels.stats.stattools import durbin_watson

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
pd.set_option('display.max_colwidth', None)

# %%
# Function to look at simple linear regression
def cesar(data, df_num, xlist):
    df_num = df_num
    
    df = pd.read_csv(data)
    df.head()

    # Keep x features and y features
    x = df[xlist]
    y = df[["y"]]

    # Initialize the LinearRegression object
    model = LinearRegression()

    # Run the model with our features
    model.fit(x, y)

    # Predicted
    y_pred = model.predict(x)
    df["y_pred"] = y_pred

    # Residuals
    residuals = df["y"] - df["y_pred"]
    df["residuals"] = residuals

    # Intercept
    intercept = round(model.intercept_[0], 3)
    # Features
    coef = round(model.coef_[0][0], 3)

    # Scatterplot for Linearity
    sns.relplot(data=df, x="X", y="y")
    plt.title(f"Scatterplot of Dataset {df_num}")
    plt.savefig(f"Scatterplot of Dataset {df_num}.png", dpi=300, bbox_inches='tight')
    plt.show()

    # Plot residuals vs. fitted values
    plt.scatter(y_pred, df["residuals"], alpha=0.6)
    plt.axhline(y=0, color='red', linestyle='--')
    plt.xlabel('Fitted Values')
    plt.ylabel('Residuals')
    plt.title('Residuals vs. Fitted Values')
    plt.savefig(f"Residuals vs. Fitted Values for Dataset {df_num}.png", dpi=300, bbox_inches='tight')
    plt.show()

    # Durbin Watson for Independence
    dubs = round(durbin_watson(residuals), 3)

    # Normality of Residuals
    sns.histplot(residuals)
    plt.title(f"Histogram_Dataset {df_num}")
    plt.savefig(f"Histogram_Dataset {df_num}.png", dpi=300, bbox_inches='tight')
    plt.show()

    print(f"Intercept: {intercept}")
    print(f"Coefficient X: {coef}")
    print(f"Durbin-Watson: {dubs}")

# %%
cesar("APMM8-assignment2-dataset10.csv", 1, ["X"])
# Out:
# /Applications/anaconda3/envs/cmpinf2120/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Intercept: 1.798
# Coefficient X: 3.059
# Durbin-Watson: 0.41

# %%
cesar("APMM8-assignment2-dataset11.csv", 2, ["X"])
# Out:
# /Applications/anaconda3/envs/cmpinf2120/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Intercept: 0.869
# Coefficient X: 2.046
# Durbin-Watson: 1.98

# %%
cesar("APMM8-assignment2-dataset13.csv", 3, ["X"])
# Out:
# /Applications/anaconda3/envs/cmpinf2120/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Intercept: 6.214
# Coefficient X: 0.024
# Durbin-Watson: 0.431

# %%
cesar("APMM8-assignment2-dataset14.csv", 4, ["X"])
# Out:
# /Applications/anaconda3/envs/cmpinf2120/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Intercept: 4.175
# Coefficient X: 2.485
# Durbin-Watson: 2.002

# %%
cesar("APMM8-assignment2-dataset15.csv", 5, ["X"])
# Out:
# /Applications/anaconda3/envs/cmpinf2120/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Intercept: 3.05
# Coefficient X: 1.49
# Durbin-Watson: 1.869

# %%
# Function to look at multiple linear regression
def cesar(data, df_num):
    df_num = df_num
    
    df = pd.read_csv(data)
    df.head()

    xlist = df.drop(columns=["y"]).columns.to_list()
    
    # Keep x features and y features
    x = df[xlist]
    y = df[["y"]]

    # Initialize the LinearRegression object
    model = LinearRegression()

    # Run the model with our features
    model.fit(x, y)

    # Predicted
    y_pred = model.predict(x)
    df["y_pred"] = y_pred

    # Residuals
    residuals = df["y"] - df["y_pred"]
    df["residuals"] = residuals

    # Intercept and coefficients
    intercept = round(model.intercept_[0], 3)
    coefs = [round(c, 3) for c in model.coef_[0]]
    
    # Linearity plots for each predictor
    for xi in xlist:
        sns.scatterplot(data=df, x=xi, y="y")
        plt.title(f"Scatterplot of {xi} vs y (Dataset {df_num})")
        plt.xlabel(xi)
        plt.ylabel("y")
        plt.savefig(f"Scatterplot_{xi}_Dataset_{df_num}.png", dpi=300, bbox_inches='tight')
        plt.show()

    # Residuals vs Fitted Values plot
    plt.scatter(df["y_pred"], df["residuals"], alpha=0.6)
    plt.axhline(y=0, color='red', linestyle='--')
    plt.xlabel('Fitted Values')
    plt.ylabel('Residuals')
    plt.title(f'Residuals vs Fitted Values (Dataset {df_num})')
    plt.savefig(f"Residuals_vs_Fitted_Dataset_{df_num}.png", dpi=300, bbox_inches='tight')
    plt.show()

    # Durbin-Watson test for independence
    dubs = round(durbin_watson(df["residuals"]), 3)

    # Histogram of residuals
    sns.histplot(df["residuals"], kde=True)
    plt.title(f"Histogram of Residuals (Dataset {df_num})")
    plt.savefig(f"Histogram_Residuals_Dataset_{df_num}.png", dpi=300, bbox_inches='tight')
    plt.show()

    # Multicollinearity (VIF)
    x_add = sm.add_constant(x)  # Adds intercept term

    vif_data = pd.DataFrame()
    vif_data["Feature"] = x_add.columns
    vif_data["VIF"] = [variance_inflation_factor(x_add.values, i)
                       for i in range(x_add.shape[1])]

    # Correlation matrix heatmap
    corr_matrix = x.corr()

    plt.figure(figsize=(10, 8))
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0, vmin=-1, vmax=1)
    plt.title(f"Correlation Heatmap of Predictors (Dataset {df_num})")
    plt.savefig(f"Correlation_Heatmap_Dataset_{df_num}.png", dpi=300, bbox_inches='tight')
    plt.show()

    # Print results
    print(f"Intercept: {intercept}")
    for i, coef in enumerate(coefs):
        print(f"Coefficient for {xlist[i]}: {coef}")
    print(f"Durbin-Watson: {dubs}")
    print("\nVariance Inflation Factors (VIF):")
    print(vif_data)

    # Store all important outputs in a dictionary
    results = {
        "data": data,
        "dataset": df_num,
        "intercept": intercept,
        "coefficients": dict(zip(xlist, coefs)),
        "durbin_watson": dubs,
        "vif": vif_data,
        "correlation_matrix": corr_matrix,
        "residuals": df["residuals"],
        "predictions": df["y_pred"]
    }

    return results

# %%
cesar("APMM8-assignment2-dataset21.csv", 21)
# Out:
# Intercept: 2.82
# Coefficient for X1: 1.135
# Coefficient for X2: -1.785
# Coefficient for X3: 3.249
# Coefficient for X4: 0.802
# Durbin-Watson: 2.011
#
# Variance Inflation Factors (VIF):
#   Feature        VIF
# 0   const  68.759277
# 1      X1   1.005927
# 2      X2   1.004735
# 3      X3   1.004440
# 4      X4   1.003075
# {'data': 'APMM8-assignment2-dataset21.csv',
#  'dataset': 21,
#  'intercept': 2.82,
#  'coefficients': {'X1': 1.135, 'X2': -1.785, 'X3': 3.249, 'X4': 0.802},
#  'durbin_watson': 2.011,
#  'vif':   Feature        VIF
#  0   const  68.759277
#  1      X1   1.005927
#  2      X2   1.004735
#  3      X3   1.004440
#  4      X4   1.003075,
#  'correlation_matrix':           X1        X2        X3        X4
#  X1  1.000000 -0.040400  0.055580 -0.034252
#  X2 -0.040400  1.000000  0.033051  0.043879
#  X3  0.055580  0.033051  1.000000 -0.009530
#  X4 -0.034252  0.043879 -0.009530  1.000000,
#  'residuals': 0       5.451692
#  1       2.822115
#  2      11.727332
# ...

# %%
# df = pd.read_csv("APMM8-assignment2-dataset22.csv")
# df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      1000 non-null   float64
#  1   X2      1000 non-null   float64
#  2   X3      1000 non-null   float64
#  3   X4      1000 non-null   float64
#  4   y       1000 non-null   float64
# dtypes: float64(5)
# memory usage: 39.2 KB

# %%
cesar("APMM8-assignment2-dataset22.csv", 22, ["X1", "X2", "X3", "X4"])
# Out:
# Intercept: 130.433
# Coefficient for X1: 0.075
# Coefficient for X2: -4.95
# Coefficient for X3: -20.356
# Coefficient for X4: 0.019
# Durbin-Watson: 2.133
#
# Variance Inflation Factors (VIF):
#   Feature        VIF
# 0   const  72.776539
# 1      X1   1.002065
# 2      X2   1.004274
# 3      X3   1.002735
# 4      X4   1.002910

# %%
cesar("APMM8-assignment2-dataset23.csv", 23, ["X1", "X2", "X3", "X4"])
# Out:
# Intercept: 4.034
# Coefficient for X1: 0.996
# Coefficient for X2: -0.54
# Coefficient for X3: 3.206
# Coefficient for X4: 0.796
# Durbin-Watson: 1.982
#
# Variance Inflation Factors (VIF):
#   Feature         VIF
# 0   const   56.648174
# 1      X1  128.794329
# 2      X2  128.790165
# 3      X3    1.000759
# 4      X4    1.001425
# {'data': 'APMM8-assignment2-dataset23.csv',
#  'dataset': 23,
#  'intercept': 4.034,
#  'coefficients': {'X1': 0.996, 'X2': -0.54, 'X3': 3.206, 'X4': 0.796},
#  'durbin_watson': 1.982,
#  'vif':   Feature         VIF
#  0   const   56.648174
#  1      X1  128.794329
#  2      X2  128.790165
#  3      X3    1.000759
#  4      X4    1.001425,
#  'correlation_matrix':           X1        X2        X3        X4
#  X1  1.000000  0.996108 -0.005984 -0.008017
#  X2  0.996108  1.000000 -0.005943 -0.005762
#  X3 -0.005984 -0.005943  1.000000 -0.026823
#  X4 -0.008017 -0.005762 -0.026823  1.000000,
#  'residuals': 0      6.388117
#  1     -4.693613
# ...

# %%
featlist = [10, 11, 13, 14, 15, 21, 22, 23, 24, 25]

# %%
results_list = []

for x in featlist:
    results = cesar(f"APMM8-assignment2-dataset{x}.csv", x)
    results_list.append(results)
# Out:
# Intercept: 1.798
# Coefficient for X: 3.059
# Durbin-Watson: 0.41
#
# Variance Inflation Factors (VIF):
#   Feature       VIF
# 0   const  3.994006
# 1       X  1.000000
# Intercept: 0.869
# Coefficient for X: 2.046
# Durbin-Watson: 1.98
#
# Variance Inflation Factors (VIF):
#   Feature       VIF
# 0   const  3.994006
# 1       X  1.000000
# Intercept: 6.214
# Coefficient for X: 0.024
# Durbin-Watson: 0.431
#
# Variance Inflation Factors (VIF):
#   Feature  VIF
# 0   const  1.0
# 1       X  1.0
# Intercept: 4.175
# Coefficient for X: 2.485
# Durbin-Watson: 2.002
#
# Variance Inflation Factors (VIF):
#   Feature       VIF
# 0   const  3.819078
# 1       X  1.000000
# Intercept: 3.05
# Coefficient for X: 1.49
# Durbin-Watson: 1.869
#
# Variance Inflation Factors (VIF):
#   Feature       VIF
# 0   const  3.994006
# 1       X  1.000000
# Intercept: 2.82
# Coefficient for X1: 1.135
# Coefficient for X2: -1.785
# Coefficient for X3: 3.249
# Coefficient for X4: 0.802
# Durbin-Watson: 2.011
# ...

# %%
results_df = pd.DataFrame(results_list)

# %%
results_df.loc[results_df.dataset == 10]
# Out:
#                               data  dataset  intercept  coefficients  \
# 0  APMM8-assignment2-dataset10.csv       10      1.798  {'X': 3.059}
#
#    durbin_watson                                                          vif  \
# 0           0.41    Feature       VIF
# 0   const  3.994006
# 1       X  1.000000
#
#   correlation_matrix  \
# 0           X
# X  1.0
#
#                                                                                                                                                                                                                        residuals  \
# 0  0      0.698848
# 1      0.460647
# 2      1.055919
# 3      2.407360
# 4      1.731211
#          ...
# 995   -2.718653
# 996   -0.455659
# 997    0.197775
# 998   -0.491619
# 999    0.100508
# Name: residuals, Length: 1000, dtype: float64
#
# ...

# %%
results_df.loc[results_df.dataset == 11]
# Out:
#                               data  dataset  intercept  coefficients  \
# 1  APMM8-assignment2-dataset11.csv       11      0.869  {'X': 2.046}
#
#    durbin_watson                                                          vif  \
# 1           1.98    Feature       VIF
# 0   const  3.994006
# 1       X  1.000000
#
#   correlation_matrix  \
# 1           X
# X  1.0
#
#                                                                                                                                                                                                                        residuals  \
# 1  0      0.379372
# 1      0.060801
# 2      0.459776
# 3      0.911734
# 4      0.007883
#          ...
# 995   -1.726260
# 996    8.637857
# 997    2.871699
# 998   -3.180523
# 999    2.535254
# Name: residuals, Length: 1000, dtype: float64
#
# ...

# %%
results_df.loc[results_df.dataset == 13]
# Out:
#                               data  dataset  intercept  coefficients  \
# 2  APMM8-assignment2-dataset13.csv       13      6.214  {'X': 0.024}
#
#    durbin_watson                                           vif  \
# 2          0.431    Feature  VIF
# 0   const  1.0
# 1       X  1.0
#
#   correlation_matrix  \
# 2           X
# X  1.0
#
#                                                                                                                                                                                                                                   residuals  \
# 2  0       9.399940
# 1       8.079742
# 2       9.601508
# 3      11.302150
# 4       7.737844
#          ...
# 995     7.405507
# 996    11.612539
# 997     9.348411
# 998     6.974026
# 999     9.311309
# Name: residuals, Length: 1000, dtype: float64
#
# ...

# %%
results_df.loc[results_df.dataset == 14]
# Out:
#                               data  dataset  intercept  coefficients  \
# 3  APMM8-assignment2-dataset14.csv       14      4.175  {'X': 2.485}
#
#    durbin_watson                                                          vif  \
# 3          2.002    Feature       VIF
# 0   const  3.819078
# 1       X  1.000000
#
#   correlation_matrix  \
# 3           X
# X  1.0
#
#                                                                                                                                                                                                                        residuals  \
# 3  0      0.060894
# 1     -1.362968
# 2      0.318719
# 3      0.528469
# 4      0.409160
#          ...
# 995   -1.480627
# 996   -0.644563
# 997   -0.190640
# 998   -0.457000
# 999   -0.798166
# Name: residuals, Length: 1000, dtype: float64
#
# ...

# %%
results_df.loc[results_df.dataset == 15]
# Out:
#                               data  dataset  intercept coefficients  \
# 4  APMM8-assignment2-dataset15.csv       15       3.05  {'X': 1.49}
#
#    durbin_watson                                                          vif  \
# 4          1.869    Feature       VIF
# 0   const  3.994006
# 1       X  1.000000
#
#   correlation_matrix  \
# 4           X
# X  1.0
#
#                                                                                                                                                                                                                        residuals  \
# 4  0     -0.553011
# 1      1.987942
# 2      0.294666
# 3     -0.109038
# 4     -0.852256
#          ...
# 995   -0.827081
# 996    1.569668
# 997   -0.775802
# 998    2.077658
# 999   -0.332132
# Name: residuals, Length: 1000, dtype: float64
#
# ...

# %%
results_df.loc[results_df.dataset == 21]
# Out:
#                               data  dataset  intercept  \
# 5  APMM8-assignment2-dataset21.csv       21       2.82
#
#                                             coefficients  durbin_watson  \
# 5  {'X1': 1.135, 'X2': -1.785, 'X3': 3.249, 'X4': 0.802}          2.011
#
#                                                                                                                              vif  \
# 5    Feature        VIF
# 0   const  68.759277
# 1      X1   1.005927
# 2      X2   1.004735
# 3      X3   1.004440
# 4      X4   1.003075
#
#                                                                                                                                                                                                        correlation_matrix  \
# 5            X1        X2        X3        X4
# X1  1.000000 -0.040400  0.055580 -0.034252
# X2 -0.040400  1.000000  0.033051  0.043879
# X3  0.055580  0.033051  1.000000 -0.009530
# X4 -0.034252  0.043879 -0.009530  1.000000
# ...

# %%
results_df.loc[results_df.dataset == 22]
# Out:
#                               data  dataset  intercept  \
# 6  APMM8-assignment2-dataset22.csv       22    130.433
#
#                                              coefficients  durbin_watson  \
# 6  {'X1': 0.075, 'X2': -4.95, 'X3': -20.356, 'X4': 0.019}          2.133
#
#                                                                                                                              vif  \
# 6    Feature        VIF
# 0   const  72.776539
# 1      X1   1.002065
# 2      X2   1.004274
# 3      X3   1.002735
# 4      X4   1.002910
#
#                                                                                                                                                                                                        correlation_matrix  \
# 6            X1        X2        X3        X4
# X1  1.000000 -0.031283 -0.031317 -0.003854
# X2 -0.031283  1.000000 -0.031112 -0.046443
# X3 -0.031317 -0.031112  1.000000 -0.025115
# ...

# %%
results_df.loc[results_df.dataset == 23]
# Out:
#                               data  dataset  intercept  \
# 7  APMM8-assignment2-dataset23.csv       23      4.034
#
#                                            coefficients  durbin_watson  \
# 7  {'X1': 0.996, 'X2': -0.54, 'X3': 3.206, 'X4': 0.796}          1.982
#
#                                                                                                                                    vif  \
# 7    Feature         VIF
# 0   const   56.648174
# 1      X1  128.794329
# 2      X2  128.790165
# 3      X3    1.000759
# 4      X4    1.001425
#
#                                                                                                                                                                                                        correlation_matrix  \
# 7            X1        X2        X3        X4
# X1  1.000000  0.996108 -0.005984 -0.008017
# X2  0.996108  1.000000 -0.005943 -0.005762
# X3 -0.005984 -0.005943  1.000000 -0.026823
# ...
